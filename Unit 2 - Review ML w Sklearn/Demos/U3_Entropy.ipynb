# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import math

pd.set_option('display.max_columns',100)
pd.set_option('display.max_rows',100)
pd.set_option("display.precision", 4)

plt.style.use('dark_background')

# %% [markdown]
# # Entropy

# %%
def entropy( P, b ):
    s = 0
    for p in P:
        if p > 0:
            s += -p*math.log(p,b)
        # end
    # end
    return s
# end

# %%
p = np.zeros((100,2))
p[:,0] = np.linspace(0,1,100)
p[:,1] = 1 - p[:,0]

ents = [ entropy(x,2) for x in p ]

plt.plot( p[:,0], ents )

# %%
n = 5

a = 2
x = np.exp( -np.arange(n) / a )
x = x / x.sum()

print(entropy(x, 2))

sns.barplot(x=np.arange(n), y=x);
plt.ylim(0,1);
# Out:
# 2.0115280009976724

# %%
x = np.random.normal(0.5,2.5,5000)
xlim = [-10,10]
bins = 100

counts, _ = np.histogram(x, bins=bins, range=xlim)
counts = counts / counts.sum()
print(entropy(counts,2))

sns.histplot(x,bins=bins,binrange=xlim);
#plt.ylim(0,1000);
# Out:
# 5.680624203271397

# %% [markdown]
# # Cross entropy

# %%
def cross_entropy( P, Q, b ):
    s = 0
    for i in range(len(P)):
        if Q[i] > 0:
            s += -P[i]*math.log(Q[i],b)
        # end
    # end
    return s
# end

# %%
n = 3

a = 0.001
x = np.exp( -np.arange(n) / a )
x = x / x.sum()

b = 0.3
y = np.exp( -np.arange(n) / b )
y = y / y.sum()

print(cross_entropy(x, y, 2))

plt.plot(np.arange(n), x, 'b');
plt.plot(np.arange(n), y, 'r');
plt.ylim(0,1);
# Out:
# 0.052341638866982974
