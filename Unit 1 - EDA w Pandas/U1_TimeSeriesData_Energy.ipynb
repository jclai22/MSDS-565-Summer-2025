# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

pd.set_option('display.max_columns',100)
pd.set_option('display.max_rows',100)

plt.style.use('dark_background')

# %% [markdown]
# # Read and clean data

# %%
df = pd.read_csv('../../../Data/Hourly Energy Consumption/DAYTON_hourly.csv', index_col=0 , header=0)

# convert index to datetime
df.index = pd.to_datetime(df.index)

# temporal sort (a few rows are out of order)
df = df.sort_index()

# because i'm lazy and don't want to type so much
df = df.rename(columns={'DAYTON_MW':'mw'})

# remove duplicate days
df = df[~df.index.duplicated(keep='first')]

# insert a few missing hours
dates = pd.Series(pd.date_range(start=df.index.min(), end=df.index.max(), freq='H'), name='date')
df = pd.merge(df, dates, left_index=True, right_on='date', how='right')
df = df.set_index('date').sort_index()
df = df.ffill()

display(df.info())
display(df.head())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 121296 entries, 2004-10-01 01:00:00 to 2018-08-03 00:00:00
# Data columns (total 1 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   mw      121296 non-null  float64
# dtypes: float64(1)
# memory usage: 1.9 MB
# C:\Users\Graham West\AppData\Local\Temp\ipykernel_6832\928752199.py:16: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   dates = pd.Series(pd.date_range(start=df.index.min(), end=df.index.max(), freq='H'), name='date')
# None
#                          mw
# date
# 2004-10-01 01:00:00  1621.0
# 2004-10-01 02:00:00  1536.0
# 2004-10-01 03:00:00  1500.0
# 2004-10-01 04:00:00  1434.0
# 2004-10-01 05:00:00  1489.0

# %% [markdown]
# # Exploring the data

# %% [markdown]
# ## Basic plot

# %%
plt.figure(figsize=(15,7))
df.mw.plot()
# Out:
# <Axes: xlabel='date'>

# %% [markdown]
# ## Advanced plot
# - change xticks
# - draw certical red lines to mark years

# %%
plt.figure(figsize=(15,7))
df.mw.plot()

for date in pd.date_range(start=df.index.min(), end=df.index.max(), freq='Y'):
    plt.axvline(x=date, color='red', linestyle='--')
# end
# Out:
# C:\Users\Graham West\AppData\Local\Temp\ipykernel_6832\1000637493.py:4: FutureWarning: 'Y' is deprecated and will be removed in a future version, please use 'YE' instead.
#   for date in pd.date_range(start=df.index.min(), end=df.index.max(), freq='Y'):

# %% [markdown]
# ## Plot one week of data

# %%
df_week = df.iloc[:24*7].copy()
df_week.mw.plot()

for date in pd.date_range(start=df_week.index.min(), end=df_week.index.max(), freq='D'):
    plt.axvline(x=date, color='red', linestyle='--')
# end

# %% [markdown]
# ## Plot one month of data

# %%
df_month = df.iloc[:24*31]
df_month.mw.plot()

for date in pd.date_range(start=df_month.index.min(), end=df_month.index.max(), freq='W-Mon'):
    plt.axvline(x=date, color='red', linestyle='--')
# end

# %% [markdown]
# ## Plot three years of data

# %%
plt.figure(figsize=(15,7))
df_year = df.iloc[:24*365*3]
df_year.mw.plot()

for date in pd.date_range(start=df_year.index.min(), end=df_year.index.max(), freq='M'):
    plt.axvline(x=date, color='red', linestyle='--')
# end
# Out:
# C:\Users\Graham West\AppData\Local\Temp\ipykernel_6832\3951621553.py:5: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   for date in pd.date_range(start=df_year.index.min(), end=df_year.index.max(), freq='M'):

# %% [markdown]
# # Datetime attribute

# %%
df['hour'] = df.index.hour
df['dayofweek'] = df.index.dayofweek # monday = 0
df['week'] = df.index.isocalendar().week
df['dayofmonth'] = df.index.day
df['month'] = df.index.month
df['quarter'] = df.index.quarter
df['dayofyear'] = df.index.dayofyear
df['year'] = df.index.year

df
# Out:
#                          mw  hour  dayofweek  week  dayofmonth  month  \
# date
# 2004-10-01 01:00:00  1621.0     1          4    40           1     10
# 2004-10-01 02:00:00  1536.0     2          4    40           1     10
# 2004-10-01 03:00:00  1500.0     3          4    40           1     10
# 2004-10-01 04:00:00  1434.0     4          4    40           1     10
# 2004-10-01 05:00:00  1489.0     5          4    40           1     10
# ...                     ...   ...        ...   ...         ...    ...
# 2018-08-02 20:00:00  2554.0    20          3    31           2      8
# 2018-08-02 21:00:00  2481.0    21          3    31           2      8
# 2018-08-02 22:00:00  2405.0    22          3    31           2      8
# 2018-08-02 23:00:00  2250.0    23          3    31           2      8
# 2018-08-03 00:00:00  2042.0     0          4    31           3      8
#
#                      quarter  dayofyear  year
# date
# 2004-10-01 01:00:00        4        275  2004
# 2004-10-01 02:00:00        4        275  2004
# 2004-10-01 03:00:00        4        275  2004
# 2004-10-01 04:00:00        4        275  2004
# 2004-10-01 05:00:00        4        275  2004
# ...                      ...        ...   ...
# 2018-08-02 20:00:00        3        214  2018
# 2018-08-02 21:00:00        3        214  2018
# 2018-08-02 22:00:00        3        214  2018
# 2018-08-02 23:00:00        3        214  2018
# 2018-08-03 00:00:00        3        215  2018
#
# [121296 rows x 9 columns]

# %% [markdown]
# ## Plotting energy distributions for different timescales

# %%
for c in df.columns[1:]:
    print(c)
    plt.figure(figsize=(15,6))
    sns.boxplot( data=df, x=c, y='mw' )
    plt.show()
# Out:
# hour
# dayofweek
# week
# dayofmonth
# month
# quarter
# dayofyear
# year

# %% [markdown]
# # Rolling, shift, diff methods

# %%
nPts   = 24*7*4
window = 24

df['mw_avg'] = df.mw.rolling(window, center=False).mean()
#df.dropna()

plt.figure(figsize=(15,6))
df.iloc[:nPts].mw.plot(c='r')
df.iloc[:nPts].mw_avg.plot(c='g')
plt.show()

plt.figure(figsize=(15,6))
(df.mw - df.mw_avg)[:nPts].plot()
plt.show()

# %%
df['mw_shift'] = df.mw.shift(1)

df[['mw','mw_shift']]
# Out:
#                          mw  mw_shift
# date
# 2004-10-01 01:00:00  1621.0       NaN
# 2004-10-01 02:00:00  1536.0    1621.0
# 2004-10-01 03:00:00  1500.0    1536.0
# 2004-10-01 04:00:00  1434.0    1500.0
# 2004-10-01 05:00:00  1489.0    1434.0
# ...                     ...       ...
# 2018-08-02 20:00:00  2554.0    2600.0
# 2018-08-02 21:00:00  2481.0    2554.0
# 2018-08-02 22:00:00  2405.0    2481.0
# 2018-08-02 23:00:00  2250.0    2405.0
# 2018-08-03 00:00:00  2042.0    2250.0
#
# [121275 rows x 2 columns]

# %%
df['mw_diff'] = df.mw.diff(periods=1)

df[['mw','mw_diff']]
# Out:
#                          mw  mw_diff
# date
# 2004-10-01 01:00:00  1621.0      NaN
# 2004-10-01 02:00:00  1536.0    -85.0
# 2004-10-01 03:00:00  1500.0    -36.0
# 2004-10-01 04:00:00  1434.0    -66.0
# 2004-10-01 05:00:00  1489.0     55.0
# ...                     ...      ...
# 2018-08-02 20:00:00  2554.0    -46.0
# 2018-08-02 21:00:00  2481.0    -73.0
# 2018-08-02 22:00:00  2405.0    -76.0
# 2018-08-02 23:00:00  2250.0   -155.0
# 2018-08-03 00:00:00  2042.0   -208.0
#
# [121296 rows x 2 columns]

# %%
df['mw_pct_ch'] = df.mw.pct_change(periods=1)

df[['mw','mw_pct_ch']]
# Out:
#                          mw  mw_pct_ch
# date
# 2004-10-01 01:00:00  1621.0        NaN
# 2004-10-01 02:00:00  1536.0  -0.052437
# 2004-10-01 03:00:00  1500.0  -0.023438
# 2004-10-01 04:00:00  1434.0  -0.044000
# 2004-10-01 05:00:00  1489.0   0.038354
# ...                     ...        ...
# 2018-08-02 20:00:00  2554.0  -0.017692
# 2018-08-02 21:00:00  2481.0  -0.028583
# 2018-08-02 22:00:00  2405.0  -0.030633
# 2018-08-02 23:00:00  2250.0  -0.064449
# 2018-08-03 00:00:00  2042.0  -0.092444
#
# [121296 rows x 2 columns]

# %% [markdown]
# ## Resample, ffill, bfill

# %%
s = df.mw.resample('5min').sum().head(50)
s[ s==0.0 ] = np.nan
s
# Out:
# date
# 2004-10-01 01:00:00    1621.0
# 2004-10-01 01:05:00       NaN
# 2004-10-01 01:10:00       NaN
# 2004-10-01 01:15:00       NaN
# 2004-10-01 01:20:00       NaN
# 2004-10-01 01:25:00       NaN
# 2004-10-01 01:30:00       NaN
# 2004-10-01 01:35:00       NaN
# 2004-10-01 01:40:00       NaN
# 2004-10-01 01:45:00       NaN
# 2004-10-01 01:50:00       NaN
# 2004-10-01 01:55:00       NaN
# 2004-10-01 02:00:00    1536.0
# 2004-10-01 02:05:00       NaN
# 2004-10-01 02:10:00       NaN
# 2004-10-01 02:15:00       NaN
# 2004-10-01 02:20:00       NaN
# 2004-10-01 02:25:00       NaN
# 2004-10-01 02:30:00       NaN
# 2004-10-01 02:35:00       NaN
# 2004-10-01 02:40:00       NaN
# 2004-10-01 02:45:00       NaN
# 2004-10-01 02:50:00       NaN
# 2004-10-01 02:55:00       NaN
# 2004-10-01 03:00:00    1500.0
# 2004-10-01 03:05:00       NaN
# 2004-10-01 03:10:00       NaN
# 2004-10-01 03:15:00       NaN
# 2004-10-01 03:20:00       NaN
# 2004-10-01 03:25:00       NaN
# 2004-10-01 03:30:00       NaN
# 2004-10-01 03:35:00       NaN
# 2004-10-01 03:40:00       NaN
# 2004-10-01 03:45:00       NaN
# 2004-10-01 03:50:00       NaN
# 2004-10-01 03:55:00       NaN
# 2004-10-01 04:00:00    1434.0
# 2004-10-01 04:05:00       NaN
# 2004-10-01 04:10:00       NaN
# 2004-10-01 04:15:00       NaN
# 2004-10-01 04:20:00       NaN
# 2004-10-01 04:25:00       NaN
# 2004-10-01 04:30:00       NaN
# 2004-10-01 04:35:00       NaN
# 2004-10-01 04:40:00       NaN
# 2004-10-01 04:45:00       NaN
# 2004-10-01 04:50:00       NaN
# 2004-10-01 04:55:00       NaN
# 2004-10-01 05:00:00    1489.0
# 2004-10-01 05:05:00       NaN
# Freq: 5min, Name: mw, dtype: float64

# %%
s.ffill().plot()
s.bfill().plot()
# Out:
# <Axes: xlabel='date'>

# %% [markdown]
# # Seasonal trend analysis with LOESS (STL)

# %%
from statsmodels.tsa.seasonal import STL

y = df.mw[:24*7*4*6]

# Perform STL decomposition
stl = STL(y, period=24*7)
result = stl.fit()

y_trend    = result.trend
y_seasonal = result.seasonal
y_resid    = result.resid

# Plot the original time series and its components
plt.figure(figsize=(15, 12))

plt.subplot(4, 1, 1)
plt.plot(y, 'r', label='Original Data')
plt.plot(y_trend, 'g', label='Trend')
#plt.plot(y_trend + y_seasonal, 'b--', label='Seasonal')
plt.legend()
plt.title('Original Time Series Data')

plt.subplot(4, 1, 2)
plt.plot(y_trend, label='Trend')
plt.legend()
plt.title('Trend Component')

plt.subplot(4, 1, 3)
plt.plot(y_seasonal, label='Seasonal')
plt.legend()
plt.title('Seasonal Component')

plt.subplot(4, 1, 4)
plt.plot(y_resid, label='Residual')
plt.legend()
plt.title('Residual Component')

plt.tight_layout()
plt.show()
