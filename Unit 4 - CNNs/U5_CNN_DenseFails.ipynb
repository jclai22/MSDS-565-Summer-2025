# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from tqdm import tqdm
import warnings
warnings.filterwarnings("ignore")

pd.set_option('display.max_columns',100)
pd.set_option('display.max_rows',100)

plt.style.use('dark_background')

# %% [markdown]
# # sklearn digits dataset
#
# Images are 8x8 pixels.

# %% [markdown]
# ## Load data

# %%
from sklearn.datasets import load_digits

# Load the digits dataset
digits = load_digits()
print( dir(digits) )
# Out:
# ['DESCR', 'data', 'feature_names', 'frame', 'images', 'target', 'target_names']

# %%
# Pick a random index
idx = np.random.randint(0, len(digits.images))

# Display the image
plt.figure(figsize=(4, 4))
plt.imshow(digits.images[idx], cmap='gray')
plt.title(f"Label: {digits.target[idx]}")
plt.axis('off')
plt.show()

# %% [markdown]
# ## Create/train/analyze model

# %%
X = digits.data
y = digits.target

print(X.shape)
# Out:
# (1797, 64)

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    X, y,
    test_size=0.2,
    stratify=y
)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import *
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping

dropout_rate = 0.1

n_features = X.shape[1]
n_classes  = np.unique(y).shape[0]

# Create model
model = Sequential([
    Input(shape=(n_features,)),
    
    Dense(32, activation='relu'),
    BatchNormalization(),
    Dropout(dropout_rate),
    
    Dense(16, activation='relu'),
    BatchNormalization(),
    Dropout(dropout_rate),
    
    Dense(8, activation='relu'),
    
    Dense(n_classes, activation='softmax'),
])

# Define the optimizer with a custom learning rate
optimizer = Adam(learning_rate=0.01)

# Compile model
model.compile(
    optimizer=optimizer,
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

# Early stopping callback
early_stopping = EarlyStopping(
    monitor='val_loss',  # Monitor validation loss
    patience=25,          # Stop after 5 epochs without improvement
    restore_best_weights=True  # Restore the best weights after stopping
)
# Display model summary
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ dense (Dense)                        │ (None, 32)                  │           2,080 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization                  │ (None, 32)                  │             128 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 32)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 16)                  │             528 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_1                │ (None, 16)                  │              64 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_1 (Dropout)                  │ (None, 16)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 8)                   │             136 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_3 (Dense)                      │ (None, 10)                  │              90 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 3,026 (11.82 KB)
#  Trainable params: 2,930 (11.45 KB)
#  Non-trainable params: 96 (384.00 B)

# %%
history = model.fit(
    X_train, y_train,
    epochs=100,
    batch_size=64,
    validation_data=(X_test, y_test),
    verbose=1,
    callbacks=[early_stopping]
)
# Out:
# Epoch 1/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - accuracy: 0.2570 - loss: 2.0035 - val_accuracy: 0.3806 - val_loss: 1.8918
# Epoch 2/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6603 - loss: 1.0620 - val_accuracy: 0.6611 - val_loss: 1.5130
# Epoch 3/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8197 - loss: 0.6198 - val_accuracy: 0.7778 - val_loss: 0.8543
# Epoch 4/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8871 - loss: 0.3957 - val_accuracy: 0.9194 - val_loss: 0.2557
# Epoch 5/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9259 - loss: 0.2623 - val_accuracy: 0.9194 - val_loss: 0.3550
# Epoch 6/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9287 - loss: 0.2249 - val_accuracy: 0.9194 - val_loss: 0.3213
# Epoch 7/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9448 - loss: 0.1995 - val_accuracy: 0.9083 - val_loss: 0.3261
# Epoch 8/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9383 - loss: 0.2034 - val_accuracy: 0.9250 - val_loss: 0.2439
# Epoch 9/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9489 - loss: 0.1697 - val_accuracy: 0.9361 - val_loss: 0.2873
# Epoch 10/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9432 - loss: 0.1761 - val_accuracy: 0.9667 - val_loss: 0.1220
# Epoch 11/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9389 - loss: 0.2010 - val_accuracy: 0.9417 - val_loss: 0.1692
# Epoch 12/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9622 - loss: 0.1303 - val_accuracy: 0.9750 - val_loss: 0.0950
# Epoch 13/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9679 - loss: 0.0966 - val_accuracy: 0.9778 - val_loss: 0.0839
# Epoch 14/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9662 - loss: 0.1141 - val_accuracy: 0.9722 - val_loss: 0.0787
# Epoch 15/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9729 - loss: 0.0883 - val_accuracy: 0.9778 - val_loss: 0.0942
# Epoch 16/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9585 - loss: 0.1289 - val_accuracy: 0.9556 - val_loss: 0.1170
# Epoch 17/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9670 - loss: 0.0939 - val_accuracy: 0.9750 - val_loss: 0.0939
# Epoch 18/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9737 - loss: 0.0859 - val_accuracy: 0.9583 - val_loss: 0.1276
# Epoch 19/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9524 - loss: 0.1338 - val_accuracy: 0.9833 - val_loss: 0.0646
# Epoch 20/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9567 - loss: 0.1260 - val_accuracy: 0.9472 - val_loss: 0.1356
# Epoch 21/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9660 - loss: 0.0967 - val_accuracy: 0.9694 - val_loss: 0.1171
# Epoch 22/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9720 - loss: 0.0795 - val_accuracy: 0.9694 - val_loss: 0.0858
# Epoch 23/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9729 - loss: 0.0766 - val_accuracy: 0.9694 - val_loss: 0.1498
# Epoch 24/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9673 - loss: 0.1108 - val_accuracy: 0.9528 - val_loss: 0.1551
# Epoch 25/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9659 - loss: 0.1163 - val_accuracy: 0.9833 - val_loss: 0.0983
# Epoch 26/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9833 - loss: 0.0737 - val_accuracy: 0.9722 - val_loss: 0.1158
# Epoch 27/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9644 - loss: 0.1113 - val_accuracy: 0.9750 - val_loss: 0.0854
# Epoch 28/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9742 - loss: 0.0871 - val_accuracy: 0.9722 - val_loss: 0.0827
# Epoch 29/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9736 - loss: 0.0849 - val_accuracy: 0.9639 - val_loss: 0.1049
# Epoch 30/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9779 - loss: 0.0732 - val_accuracy: 0.9611 - val_loss: 0.1528
# Epoch 31/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9791 - loss: 0.0726 - val_accuracy: 0.9750 - val_loss: 0.0796
# Epoch 32/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9692 - loss: 0.0841 - val_accuracy: 0.9722 - val_loss: 0.0884
# Epoch 33/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9756 - loss: 0.0805 - val_accuracy: 0.9722 - val_loss: 0.0919
# Epoch 34/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9743 - loss: 0.0673 - val_accuracy: 0.9667 - val_loss: 0.1014
# Epoch 35/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9750 - loss: 0.0651 - val_accuracy: 0.9583 - val_loss: 0.1476
# Epoch 36/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9667 - loss: 0.1008 - val_accuracy: 0.9778 - val_loss: 0.0894
# Epoch 37/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9707 - loss: 0.0849 - val_accuracy: 0.9694 - val_loss: 0.0934
# Epoch 38/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9610 - loss: 0.1228 - val_accuracy: 0.9750 - val_loss: 0.1037
# Epoch 39/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9807 - loss: 0.0598 - val_accuracy: 0.9778 - val_loss: 0.0997
# Epoch 40/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9861 - loss: 0.0532 - val_accuracy: 0.9778 - val_loss: 0.0727
# Epoch 41/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9799 - loss: 0.0643 - val_accuracy: 0.9861 - val_loss: 0.0705
# Epoch 42/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9893 - loss: 0.0399 - val_accuracy: 0.9778 - val_loss: 0.0947
# Epoch 43/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9775 - loss: 0.0688 - val_accuracy: 0.9806 - val_loss: 0.1050
# Epoch 44/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9863 - loss: 0.0502 - val_accuracy: 0.9611 - val_loss: 0.1477

# %%
from sklearn.metrics import classification_report, confusion_matrix, ConfusionMatrixDisplay

# Get predictions
y_train_pred = model.predict(X_train).argmax(axis=1)
y_test_pred  = model.predict(X_test).argmax(axis=1)

# Create a figure with two subplots side by side
fig, axes = plt.subplots(1, 2, figsize=(10, 4))

# Left subplot: Training and Validation Loss
axes[0].plot(history.history['loss'], label='Training Loss')
axes[0].plot(history.history['val_loss'], label='Validation Loss')
#axes[0].set_yscale('log')
axes[0].set_title('Training and Validation Loss')
axes[0].set_xlabel('Epochs')
axes[0].set_ylabel('Loss')
axes[0].legend()

# Right subplot: Confusion Matrix (Test Data) using seaborn heatmap with vmin set to 0
cm = confusion_matrix(y_test, y_test_pred)
sns.heatmap(cm, annot=True, fmt='d', ax=axes[1], vmin=0, 
            annot_kws={"size": 12}, cmap='nipy_spectral')
axes[1].set_title('Confusion Matrix (Test Data)')
axes[1].set_xlabel('Predicted Label')
axes[1].set_ylabel('True Label')

plt.tight_layout()
plt.show()

# Print classification report for test data
report = classification_report(y_test, y_test_pred)
print(report)
# Out:
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
#               precision    recall  f1-score   support
#
#            0       0.97      1.00      0.99        36
#            1       0.95      1.00      0.97        36
#            2       1.00      1.00      1.00        35
#            3       0.97      1.00      0.99        37
#            4       0.97      1.00      0.99        36
#            5       1.00      0.95      0.97        37
#            6       1.00      1.00      1.00        36
#            7       1.00      1.00      1.00        36
#            8       1.00      0.89      0.94        35
#            9       0.97      1.00      0.99        36
#
#     accuracy                           0.98       360
#    macro avg       0.98      0.98      0.98       360
# weighted avg       0.98      0.98      0.98       360

# %% [markdown]
# # Keras MNIST dataset
#
# Images are 28x28 pixels.

# %% [markdown]
# ## Load data

# %%
from tensorflow.keras.datasets import mnist

# Load data
(X_train, y_train), (X_test, y_test) = mnist.load_data()

# Print shapes
print("X_train.shape:", X_train.shape)
print("X_test.shape: ", X_test.shape)
# Out:
# X_train.shape: (60000, 28, 28)
# X_test.shape:  (10000, 28, 28)

# %%
# Display a random image
idx = np.random.randint(0, len(X_train))
plt.figure(figsize=(4, 4))
plt.imshow(X_train[idx], cmap='gray')
plt.title(f"Label: {y_train[idx]}")
plt.axis('off')
plt.show()

# %% [markdown]
# ## Create/train/analyze model

# %%
# flatten images into vectors
X_train_flat = X_train.reshape(X_train.shape[0],-1)
X_test_flat  = X_test.reshape(X_test.shape[0],-1)

print("X_train_flat.shape:", X_train_flat.shape)
print("X_test_flat.shape: ", X_test_flat.shape)
# Out:
# X_train_flat.shape: (60000, 784)
# X_test_flat.shape:  (10000, 784)

# %%
dropout_rate = 0.1

n_features = X_train_flat.shape[1]
n_classes  = np.unique(y_train).shape[0]

# Create model
model = Sequential([
    Input(shape=(n_features,)),
    
    Dense(32, activation='relu'),
    BatchNormalization(),
    Dropout(dropout_rate),
    
    Dense(16, activation='relu'),
    BatchNormalization(),
    Dropout(dropout_rate),
    
    Dense(8, activation='relu'),
    
    Dense(n_classes, activation='softmax'),
])

# Define the optimizer with a custom learning rate
optimizer = Adam(learning_rate=0.01)

# Compile model
model.compile(
    optimizer=optimizer,
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

# Early stopping callback
early_stopping = EarlyStopping(
    monitor='val_loss',  # Monitor validation loss
    patience=25,          # Stop after 5 epochs without improvement
    restore_best_weights=True  # Restore the best weights after stopping
)

# Display model summary
model.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ dense_4 (Dense)                      │ (None, 32)                  │          25,120 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_2                │ (None, 32)                  │             128 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_2 (Dropout)                  │ (None, 32)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_5 (Dense)                      │ (None, 16)                  │             528 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_3                │ (None, 16)                  │              64 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_3 (Dropout)                  │ (None, 16)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_6 (Dense)                      │ (None, 8)                   │             136 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_7 (Dense)                      │ (None, 10)                  │              90 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 26,066 (101.82 KB)
#  Trainable params: 25,970 (101.45 KB)
#  Non-trainable params: 96 (384.00 B)

# %%
history = model.fit(
    X_train_flat, y_train,
    epochs=100,
    batch_size=64,
    validation_data=(X_test_flat, y_test),
    verbose=1,
    callbacks=[early_stopping]
)
# Out:
# Epoch 1/100
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - accuracy: 0.7759 - loss: 0.6979 - val_accuracy: 0.9302 - val_loss: 0.2345
# Epoch 2/100
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9200 - loss: 0.2779 - val_accuracy: 0.9500 - val_loss: 0.1733
# Epoch 3/100
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9329 - loss: 0.2310 - val_accuracy: 0.9575 - val_loss: 0.1531
# Epoch 4/100
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9394 - loss: 0.2099 - val_accuracy: 0.9555 - val_loss: 0.1549
# Epoch 5/100
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9442 - loss: 0.1922 - val_accuracy: 0.9577 - val_loss: 0.1443
# Epoch 6/100
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9446 - loss: 0.1886 - val_accuracy: 0.9623 - val_loss: 0.1343
# Epoch 7/100
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9475 - loss: 0.1741 - val_accuracy: 0.9634 - val_loss: 0.1268
# Epoch 8/100
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9496 - loss: 0.1668 - val_accuracy: 0.9616 - val_loss: 0.1330
# Epoch 9/100
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9513 - loss: 0.1629 - val_accuracy: 0.9683 - val_loss: 0.1117
# Epoch 10/100
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9560 - loss: 0.1500 - val_accuracy: 0.9630 - val_loss: 0.1315
# Epoch 11/100
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9530 - loss: 0.1554 - val_accuracy: 0.9630 - val_loss: 0.1238
# Epoch 12/100
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9580 - loss: 0.1442 - val_accuracy: 0.9661 - val_loss: 0.1205
# Epoch 13/100
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9580 - loss: 0.1415 - val_accuracy: 0.9678 - val_loss: 0.1102
# Epoch 14/100
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9573 - loss: 0.1412 - val_accuracy: 0.9654 - val_loss: 0.1133
# Epoch 15/100
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9582 - loss: 0.1384 - val_accuracy: 0.9704 - val_loss: 0.1067
# Epoch 16/100
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9588 - loss: 0.1375 - val_accuracy: 0.9669 - val_loss: 0.1075
# Epoch 17/100
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9588 - loss: 0.1377 - val_accuracy: 0.9664 - val_loss: 0.1165
# Epoch 18/100
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9592 - loss: 0.1373 - val_accuracy: 0.9669 - val_loss: 0.1168
# Epoch 19/100
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9610 - loss: 0.1308 - val_accuracy: 0.9697 - val_loss: 0.1139
# Epoch 20/100
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9620 - loss: 0.1246 - val_accuracy: 0.9692 - val_loss: 0.1076
# Epoch 21/100
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9626 - loss: 0.1272 - val_accuracy: 0.9697 - val_loss: 0.1111
# Epoch 22/100
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9639 - loss: 0.1192 - val_accuracy: 0.9681 - val_loss: 0.1095
# Epoch 23/100
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9626 - loss: 0.1271 - val_accuracy: 0.9701 - val_loss: 0.1048
# Epoch 24/100
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9633 - loss: 0.1237 - val_accuracy: 0.9713 - val_loss: 0.1046
# Epoch 25/100
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9630 - loss: 0.1232 - val_accuracy: 0.9687 - val_loss: 0.1115
# Epoch 26/100
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9658 - loss: 0.1161 - val_accuracy: 0.9701 - val_loss: 0.1082
# Epoch 27/100
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9649 - loss: 0.1161 - val_accuracy: 0.9633 - val_loss: 0.1317
# Epoch 28/100
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9655 - loss: 0.1129 - val_accuracy: 0.9694 - val_loss: 0.1112
# Epoch 29/100
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9652 - loss: 0.1181 - val_accuracy: 0.9669 - val_loss: 0.1143
# Epoch 30/100
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9639 - loss: 0.1183 - val_accuracy: 0.9692 - val_loss: 0.1101
# Epoch 31/100
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9643 - loss: 0.1142 - val_accuracy: 0.9703 - val_loss: 0.1051
# Epoch 32/100
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9646 - loss: 0.1135 - val_accuracy: 0.9691 - val_loss: 0.1143
# Epoch 33/100
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9656 - loss: 0.1120 - val_accuracy: 0.9714 - val_loss: 0.1064
# Epoch 34/100
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9661 - loss: 0.1117 - val_accuracy: 0.9673 - val_loss: 0.1178
# Epoch 35/100
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9663 - loss: 0.1106 - val_accuracy: 0.9709 - val_loss: 0.1058
# Epoch 36/100
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9663 - loss: 0.1085 - val_accuracy: 0.9708 - val_loss: 0.1081
# Epoch 37/100
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9687 - loss: 0.1011 - val_accuracy: 0.9707 - val_loss: 0.1050
# Epoch 38/100
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9674 - loss: 0.1099 - val_accuracy: 0.9697 - val_loss: 0.1154
# Epoch 39/100
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9681 - loss: 0.1068 - val_accuracy: 0.9691 - val_loss: 0.1094
# Epoch 40/100
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9679 - loss: 0.1035 - val_accuracy: 0.9667 - val_loss: 0.1127
# Epoch 41/100
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9693 - loss: 0.1013 - val_accuracy: 0.9707 - val_loss: 0.1100
# Epoch 42/100
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9670 - loss: 0.1098 - val_accuracy: 0.9694 - val_loss: 0.1101
# Epoch 43/100
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9690 - loss: 0.1040 - val_accuracy: 0.9694 - val_loss: 0.1124
# Epoch 44/100
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9698 - loss: 0.1001 - val_accuracy: 0.9710 - val_loss: 0.1094
# Epoch 45/100
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9684 - loss: 0.1037 - val_accuracy: 0.9702 - val_loss: 0.1069
# Epoch 46/100
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9701 - loss: 0.0993 - val_accuracy: 0.9704 - val_loss: 0.1154
# Epoch 47/100
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9675 - loss: 0.1085 - val_accuracy: 0.9705 - val_loss: 0.1113
# Epoch 48/100
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9684 - loss: 0.1026 - val_accuracy: 0.9716 - val_loss: 0.1080
# Epoch 49/100
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9693 - loss: 0.1020 - val_accuracy: 0.9705 - val_loss: 0.1121

# %%
from sklearn.metrics import classification_report, confusion_matrix, ConfusionMatrixDisplay

# Get predictions
y_train_pred = model.predict(X_train_flat).argmax(axis=1)
y_test_pred  = model.predict(X_test_flat).argmax(axis=1)

# Create a figure with two subplots side by side
fig, axes = plt.subplots(1, 2, figsize=(10, 4))

# Left subplot: Training and Validation Loss
axes[0].plot(history.history['loss'], label='Training Loss')
axes[0].plot(history.history['val_loss'], label='Validation Loss')
#axes[0].set_yscale('log')
axes[0].set_title('Training and Validation Loss')
axes[0].set_xlabel('Epochs')
axes[0].set_ylabel('Loss')
axes[0].legend()

# Right subplot: Confusion Matrix (Test Data) using seaborn heatmap with vmin set to 0
cm = confusion_matrix(y_test, y_test_pred)
sns.heatmap(cm, annot=True, fmt='d', ax=axes[1], vmin=0, 
            annot_kws={"size": 12}, cmap='nipy_spectral')
axes[1].set_title('Confusion Matrix (Test Data)')
axes[1].set_xlabel('Predicted Label')
axes[1].set_ylabel('True Label')

plt.tight_layout()
plt.show()

# Print classification report for test data
report = classification_report(y_test, y_test_pred)
print(report)
# Out:
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 1s 510us/step
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 704us/step
#               precision    recall  f1-score   support
#
#            0       0.96      0.99      0.98       980
#            1       0.98      0.99      0.99      1135
#            2       0.98      0.96      0.97      1032
#            3       0.98      0.96      0.97      1010
#            4       0.98      0.96      0.97       982
#            5       0.96      0.98      0.97       892
#            6       0.98      0.97      0.97       958
#            7       0.97      0.96      0.97      1028
#            8       0.97      0.96      0.97       974
#            9       0.95      0.97      0.96      1009
#
#     accuracy                           0.97     10000
#    macro avg       0.97      0.97      0.97     10000
# weighted avg       0.97      0.97      0.97     10000

# %% [markdown]
# ## Predict an augmented image

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# Define the image generator with augmentation options
datagen = ImageDataGenerator(
    rotation_range=30,      # Rotate images randomly
    width_shift_range=0.2,  # Randomly shift the width of images
    height_shift_range=0.2, # Randomly shift the height of images
    zoom_range=0.2,         # Randomly zoom
    shear_range=0.1         # Apply shear transformation
)

# Pick a random test image
idx = np.random.randint(0, len(X_test))
image_orig = X_test[idx]

# Create the iterator
iterator = datagen.flow(
    image_orig[np.newaxis, :, :, np.newaxis],
    batch_size=1,
    shuffle=False
)

# Get the augmented image using Python's built-in next()
image_aug = next(iterator)[0, :, :, 0]

# Plot original and augmented image
plt.figure(figsize=(6, 3))

plt.subplot(1, 2, 1)
plt.imshow(image_orig, cmap='gray')
plt.title("Original")

plt.subplot(1, 2, 2)
plt.imshow(image_aug, cmap='gray')
plt.title("Augmented")

plt.tight_layout()
plt.show()

# Ensure image shape is (1, 28, 28, 1) and type is float32
image_orig_input = image_orig.flatten()[np.newaxis, :]
image_aug_input  = image_aug.flatten()[np.newaxis, :]

# Predict using the model
pred_orig = model.predict(image_orig_input)
pred_aug = model.predict(image_aug_input)

# Get predicted digit (argmax of class probabilities)
digit_orig = np.argmax(pred_orig)
digit_aug = np.argmax(pred_aug)

print(f"Original image prediction:  {digit_orig}")
print(f"Augmented image prediction: {digit_aug}")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# Original image prediction:  8
# Augmented image prediction: 6

# %% [markdown]
# Since only the center pixels ever have ink in them where the letters are drawn, the weights corresponding to the outer pixels don't ever get and information to train on other than 0's. This means that images which are different in scale, translation, or rotation will not be accurately predicted.

# %%
# Display a random image
plt.figure(figsize=(4, 4))
plt.imshow(X_train.mean(axis=0), cmap='gray')
plt.title(f"Avg of all images")
plt.axis('off')
plt.show()

# %% [markdown]
# # Keras MNIST w/ augmented images

# %% [markdown]
# ## Create augmented dataset

# %%
from tensorflow.keras.datasets import mnist

# Load data
(X_train, y_train), (X_test, y_test) = mnist.load_data()

# Print shapes
print("X_train.shape:", X_train.shape)
print("X_test.shape: ", X_test.shape)
# Out:
# X_train.shape: (60000, 28, 28)
# X_test.shape:  (10000, 28, 28)

# %%
# Define the image generator with augmentation options
datagen = ImageDataGenerator(
    rotation_range=30,
    width_shift_range=0.2,
    height_shift_range=0.2,
    zoom_range=0.2,
    shear_range=0.1
)

# Plot the first 3 images before augmentation
plt.figure(figsize=(10, 3))
for i in range(3):
    plt.subplot(1, 3, i + 1)
    plt.imshow(X_train[i], cmap='gray')
    plt.title(f"Original {i}")
    plt.axis('off')
plt.tight_layout()
plt.show()

# Augment X_train
iterator_train = datagen.flow(
    X_train[..., np.newaxis],
    batch_size=X_train.shape[0],
    shuffle=False
)
X_train = next(iterator_train)[..., 0]

# Plot the first 3 images after augmentation
plt.figure(figsize=(10, 3))
for i in range(3):
    plt.subplot(1, 3, i + 1)
    plt.imshow(X_train[i], cmap='gray')
    plt.title(f"Augmented {i}")
    plt.axis('off')
plt.tight_layout()
plt.show()

# Augment X_test
iterator_test = datagen.flow(
    X_test[..., np.newaxis],
    batch_size=X_test.shape[0],
    shuffle=False
)
X_test = next(iterator_test)[..., 0]

# %% [markdown]
# ## Create/train/analyze model

# %%
# flatten images into vectors
X_train_flat = X_train.reshape(X_train.shape[0],-1)
X_test_flat  = X_test.reshape(X_test.shape[0],-1)

print("X_train_flat.shape:", X_train_flat.shape)
print("X_test_flat.shape: ", X_test_flat.shape)
# Out:
# X_train_flat.shape: (60000, 784)
# X_test_flat.shape:  (10000, 784)

# %%
dropout_rate = 0.1

n_features = X_train_flat.shape[1]
n_classes  = np.unique(y_train).shape[0]

# Create model
model = Sequential([
    Input(shape=(n_features,)),
    
    Dense(32, activation='relu'),
    BatchNormalization(),
    Dropout(dropout_rate),
    
    Dense(16, activation='relu'),
    BatchNormalization(),
    Dropout(dropout_rate),
    
    Dense(8, activation='relu'),
    
    Dense(n_classes, activation='softmax'),
])

# Define the optimizer with a custom learning rate
optimizer = Adam(learning_rate=0.01)

# Compile model
model.compile(
    optimizer=optimizer,
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

# Early stopping callback
early_stopping = EarlyStopping(
    monitor='val_loss',  # Monitor validation loss
    patience=25,          # Stop after 5 epochs without improvement
    restore_best_weights=True  # Restore the best weights after stopping
)

# Display model summary
model.summary()
# Out:
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ dense_8 (Dense)                      │ (None, 32)                  │          25,120 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_4                │ (None, 32)                  │             128 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_4 (Dropout)                  │ (None, 32)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_9 (Dense)                      │ (None, 16)                  │             528 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_5                │ (None, 16)                  │              64 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_5 (Dropout)                  │ (None, 16)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_10 (Dense)                     │ (None, 8)                   │             136 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_11 (Dense)                     │ (None, 10)                  │              90 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 26,066 (101.82 KB)
#  Trainable params: 25,970 (101.45 KB)
#  Non-trainable params: 96 (384.00 B)

# %%
history = model.fit(
    X_train_flat, y_train,
    epochs=100,
    batch_size=64,
    validation_data=(X_test_flat, y_test),
    verbose=1,
    callbacks=[early_stopping]
)
# Out:
# Epoch 1/100
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.3417 - loss: 1.8336 - val_accuracy: 0.5533 - val_loss: 1.2443
# Epoch 2/100
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.5268 - loss: 1.3529 - val_accuracy: 0.6336 - val_loss: 1.0690
# Epoch 3/100
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.5669 - loss: 1.2477 - val_accuracy: 0.6658 - val_loss: 0.9900
# Epoch 4/100
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.5932 - loss: 1.1856 - val_accuracy: 0.6849 - val_loss: 0.9193
# Epoch 5/100
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.6120 - loss: 1.1278 - val_accuracy: 0.7089 - val_loss: 0.8778
# Epoch 6/100
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.6207 - loss: 1.1108 - val_accuracy: 0.7127 - val_loss: 0.8680
# Epoch 7/100
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.6383 - loss: 1.0623 - val_accuracy: 0.7227 - val_loss: 0.8528
# Epoch 8/100
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.6479 - loss: 1.0455 - val_accuracy: 0.7300 - val_loss: 0.8398
# Epoch 9/100
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.6487 - loss: 1.0336 - val_accuracy: 0.7229 - val_loss: 0.8270
# Epoch 10/100
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.6565 - loss: 1.0144 - val_accuracy: 0.7456 - val_loss: 0.7969
# Epoch 11/100
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.6620 - loss: 1.0133 - val_accuracy: 0.7437 - val_loss: 0.7985
# Epoch 12/100
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.6672 - loss: 0.9982 - val_accuracy: 0.7413 - val_loss: 0.8054
# Epoch 13/100
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.6666 - loss: 0.9883 - val_accuracy: 0.7418 - val_loss: 0.7902
# Epoch 14/100
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.6664 - loss: 0.9833 - val_accuracy: 0.7436 - val_loss: 0.7849
# Epoch 15/100
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.6695 - loss: 0.9789 - val_accuracy: 0.7454 - val_loss: 0.7805
# Epoch 16/100
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.6706 - loss: 0.9714 - val_accuracy: 0.7501 - val_loss: 0.7744
# Epoch 17/100
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.6767 - loss: 0.9734 - val_accuracy: 0.7273 - val_loss: 0.8258
# Epoch 18/100
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.6796 - loss: 0.9628 - val_accuracy: 0.7541 - val_loss: 0.7649
# Epoch 19/100
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.6767 - loss: 0.9632 - val_accuracy: 0.7518 - val_loss: 0.7795
# Epoch 20/100
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.6763 - loss: 0.9588 - val_accuracy: 0.7543 - val_loss: 0.7495
# Epoch 21/100
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.6780 - loss: 0.9587 - val_accuracy: 0.7428 - val_loss: 0.7789
# Epoch 22/100
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.6814 - loss: 0.9535 - val_accuracy: 0.7580 - val_loss: 0.7561
# Epoch 23/100
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.6824 - loss: 0.9502 - val_accuracy: 0.7589 - val_loss: 0.7545
# Epoch 24/100
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.6806 - loss: 0.9491 - val_accuracy: 0.7537 - val_loss: 0.7649
# Epoch 25/100
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.6866 - loss: 0.9397 - val_accuracy: 0.7572 - val_loss: 0.7489
# Epoch 26/100
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.6827 - loss: 0.9407 - val_accuracy: 0.7619 - val_loss: 0.7434
# Epoch 27/100
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.6894 - loss: 0.9282 - val_accuracy: 0.7524 - val_loss: 0.7702
# Epoch 28/100
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.6879 - loss: 0.9422 - val_accuracy: 0.7621 - val_loss: 0.7479
# Epoch 29/100
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.6988 - loss: 0.9178 - val_accuracy: 0.7622 - val_loss: 0.7493
# Epoch 30/100
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.6913 - loss: 0.9229 - val_accuracy: 0.7678 - val_loss: 0.7290
# Epoch 31/100
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.6882 - loss: 0.9292 - val_accuracy: 0.7613 - val_loss: 0.7361
# Epoch 32/100
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.6928 - loss: 0.9230 - val_accuracy: 0.7714 - val_loss: 0.7234
# Epoch 33/100
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.6938 - loss: 0.9157 - val_accuracy: 0.7586 - val_loss: 0.7409
# Epoch 34/100
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.6942 - loss: 0.9192 - val_accuracy: 0.7671 - val_loss: 0.7252
# Epoch 35/100
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7002 - loss: 0.9058 - val_accuracy: 0.7652 - val_loss: 0.7241
# Epoch 36/100
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.6993 - loss: 0.9127 - val_accuracy: 0.7553 - val_loss: 0.7579
# Epoch 37/100
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.6941 - loss: 0.9186 - val_accuracy: 0.7669 - val_loss: 0.7187
# Epoch 38/100
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.6955 - loss: 0.9090 - val_accuracy: 0.7644 - val_loss: 0.7272
# Epoch 39/100
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.6960 - loss: 0.9130 - val_accuracy: 0.7683 - val_loss: 0.7138
# Epoch 40/100
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.6978 - loss: 0.9071 - val_accuracy: 0.7648 - val_loss: 0.7247
# Epoch 41/100
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.6954 - loss: 0.9073 - val_accuracy: 0.7682 - val_loss: 0.7222
# Epoch 42/100
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7006 - loss: 0.8994 - val_accuracy: 0.7690 - val_loss: 0.7157
# Epoch 43/100
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7019 - loss: 0.8939 - val_accuracy: 0.7635 - val_loss: 0.7302
# Epoch 44/100
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.6999 - loss: 0.9015 - val_accuracy: 0.7691 - val_loss: 0.7210
# Epoch 45/100
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.6984 - loss: 0.8987 - val_accuracy: 0.7657 - val_loss: 0.7180
# Epoch 46/100
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7023 - loss: 0.8889 - val_accuracy: 0.7684 - val_loss: 0.7075
# Epoch 47/100
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7007 - loss: 0.8994 - val_accuracy: 0.7604 - val_loss: 0.7366
# Epoch 48/100
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7022 - loss: 0.8868 - val_accuracy: 0.7620 - val_loss: 0.7218
# Epoch 49/100
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.6987 - loss: 0.9004 - val_accuracy: 0.7660 - val_loss: 0.7119
# Epoch 50/100
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7031 - loss: 0.8893 - val_accuracy: 0.7648 - val_loss: 0.7261
# Epoch 51/100
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7069 - loss: 0.8841 - val_accuracy: 0.7643 - val_loss: 0.7270
# Epoch 52/100
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7067 - loss: 0.8908 - val_accuracy: 0.7697 - val_loss: 0.7228
# Epoch 53/100
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7031 - loss: 0.8906 - val_accuracy: 0.7571 - val_loss: 0.7322
# Epoch 54/100
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7069 - loss: 0.8877 - val_accuracy: 0.7595 - val_loss: 0.7317
# Epoch 55/100
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7049 - loss: 0.8892 - val_accuracy: 0.7687 - val_loss: 0.7082
# Epoch 56/100
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7072 - loss: 0.8754 - val_accuracy: 0.7641 - val_loss: 0.7202
# Epoch 57/100
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7090 - loss: 0.8781 - val_accuracy: 0.7708 - val_loss: 0.7054
# Epoch 58/100
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7045 - loss: 0.8840 - val_accuracy: 0.7671 - val_loss: 0.7164
# Epoch 59/100
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7094 - loss: 0.8736 - val_accuracy: 0.7683 - val_loss: 0.7167
# Epoch 60/100
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7089 - loss: 0.8748 - val_accuracy: 0.7602 - val_loss: 0.7199
# Epoch 61/100
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7053 - loss: 0.8847 - val_accuracy: 0.7669 - val_loss: 0.7209
# Epoch 62/100
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7099 - loss: 0.8724 - val_accuracy: 0.7665 - val_loss: 0.7147
# Epoch 63/100
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7076 - loss: 0.8768 - val_accuracy: 0.7675 - val_loss: 0.7158
# Epoch 64/100
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7063 - loss: 0.8859 - val_accuracy: 0.7740 - val_loss: 0.7014
# Epoch 65/100
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7109 - loss: 0.8684 - val_accuracy: 0.7678 - val_loss: 0.7082
# Epoch 66/100
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7134 - loss: 0.8654 - val_accuracy: 0.7586 - val_loss: 0.7339
# Epoch 67/100
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7054 - loss: 0.8829 - val_accuracy: 0.7672 - val_loss: 0.7214
# Epoch 68/100
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7109 - loss: 0.8688 - val_accuracy: 0.7683 - val_loss: 0.7227
# Epoch 69/100
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7074 - loss: 0.8726 - val_accuracy: 0.7669 - val_loss: 0.7129
# Epoch 70/100
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7070 - loss: 0.8749 - val_accuracy: 0.7680 - val_loss: 0.7132
# Epoch 71/100
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7105 - loss: 0.8640 - val_accuracy: 0.7689 - val_loss: 0.7062
# Epoch 72/100
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7142 - loss: 0.8642 - val_accuracy: 0.7683 - val_loss: 0.7161
# Epoch 73/100
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7111 - loss: 0.8686 - val_accuracy: 0.7705 - val_loss: 0.7012
# Epoch 74/100
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7122 - loss: 0.8598 - val_accuracy: 0.7629 - val_loss: 0.7262
# Epoch 75/100
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7127 - loss: 0.8648 - val_accuracy: 0.7731 - val_loss: 0.6993
# Epoch 76/100
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7121 - loss: 0.8650 - val_accuracy: 0.7657 - val_loss: 0.7075
# Epoch 77/100
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7115 - loss: 0.8661 - val_accuracy: 0.7698 - val_loss: 0.7089
# Epoch 78/100
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7153 - loss: 0.8583 - val_accuracy: 0.7668 - val_loss: 0.7073
# Epoch 79/100
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7126 - loss: 0.8572 - val_accuracy: 0.7714 - val_loss: 0.7028
# Epoch 80/100
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7169 - loss: 0.8575 - val_accuracy: 0.7646 - val_loss: 0.7179
# Epoch 81/100
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7103 - loss: 0.8683 - val_accuracy: 0.7695 - val_loss: 0.7025
# Epoch 82/100
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7163 - loss: 0.8492 - val_accuracy: 0.7692 - val_loss: 0.6990
# Epoch 83/100
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7145 - loss: 0.8598 - val_accuracy: 0.7742 - val_loss: 0.7010
# Epoch 84/100
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7191 - loss: 0.8479 - val_accuracy: 0.7676 - val_loss: 0.7092
# Epoch 85/100
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7162 - loss: 0.8482 - val_accuracy: 0.7633 - val_loss: 0.7210
# Epoch 86/100
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7111 - loss: 0.8543 - val_accuracy: 0.7644 - val_loss: 0.7152
# Epoch 87/100
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7173 - loss: 0.8487 - val_accuracy: 0.7728 - val_loss: 0.7031
# Epoch 88/100
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7132 - loss: 0.8572 - val_accuracy: 0.7727 - val_loss: 0.7029
# Epoch 89/100
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7173 - loss: 0.8472 - val_accuracy: 0.7659 - val_loss: 0.7146
# Epoch 90/100
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7135 - loss: 0.8497 - val_accuracy: 0.7711 - val_loss: 0.7023
# Epoch 91/100
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7168 - loss: 0.8482 - val_accuracy: 0.7657 - val_loss: 0.7124
# Epoch 92/100
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7208 - loss: 0.8393 - val_accuracy: 0.7689 - val_loss: 0.7003
# Epoch 93/100
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7200 - loss: 0.8424 - val_accuracy: 0.7716 - val_loss: 0.7087
# Epoch 94/100
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7179 - loss: 0.8471 - val_accuracy: 0.7633 - val_loss: 0.7319
# Epoch 95/100
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7145 - loss: 0.8546 - val_accuracy: 0.7742 - val_loss: 0.6915
# Epoch 96/100
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7154 - loss: 0.8503 - val_accuracy: 0.7705 - val_loss: 0.6953
# Epoch 97/100
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7199 - loss: 0.8391 - val_accuracy: 0.7739 - val_loss: 0.6981
# Epoch 98/100
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7182 - loss: 0.8497 - val_accuracy: 0.7574 - val_loss: 0.7378
# Epoch 99/100
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7167 - loss: 0.8505 - val_accuracy: 0.7749 - val_loss: 0.6959
# Epoch 100/100
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7241 - loss: 0.8262 - val_accuracy: 0.7702 - val_loss: 0.7036

# %%
from sklearn.metrics import classification_report, confusion_matrix, ConfusionMatrixDisplay

# Get predictions
y_train_pred = model.predict(X_train_flat).argmax(axis=1)
y_test_pred  = model.predict(X_test_flat).argmax(axis=1)

# Create a figure with two subplots side by side
fig, axes = plt.subplots(1, 2, figsize=(10, 4))

# Left subplot: Training and Validation Loss
axes[0].plot(history.history['loss'], label='Training Loss')
axes[0].plot(history.history['val_loss'], label='Validation Loss')
#axes[0].set_yscale('log')
axes[0].set_title('Training and Validation Loss')
axes[0].set_xlabel('Epochs')
axes[0].set_ylabel('Loss')
axes[0].legend()

# Right subplot: Confusion Matrix (Test Data) using seaborn heatmap with vmin set to 0
cm = confusion_matrix(y_test, y_test_pred)
sns.heatmap(cm, annot=True, fmt='d', ax=axes[1], vmin=0, 
            annot_kws={"size": 12}, cmap='nipy_spectral')
axes[1].set_title('Confusion Matrix (Test Data)')
axes[1].set_xlabel('Predicted Label')
axes[1].set_ylabel('True Label')

plt.tight_layout()
plt.show()

# Print classification report for test data
report = classification_report(y_test, y_test_pred)
print(report)
# Out:
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 1s 526us/step
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 717us/step
#               precision    recall  f1-score   support
#
#            0       0.85      0.88      0.86       980
#            1       0.93      0.94      0.94      1135
#            2       0.79      0.76      0.77      1032
#            3       0.74      0.62      0.68      1010
#            4       0.77      0.71      0.74       982
#            5       0.67      0.62      0.64       892
#            6       0.78      0.87      0.82       958
#            7       0.79      0.81      0.80      1028
#            8       0.69      0.73      0.71       974
#            9       0.70      0.76      0.73      1009
#
#     accuracy                           0.77     10000
#    macro avg       0.77      0.77      0.77     10000
# weighted avg       0.77      0.77      0.77     10000
