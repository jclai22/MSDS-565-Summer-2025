# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from tqdm import tqdm
import warnings
warnings.filterwarnings("ignore")

pd.set_option('display.max_columns',100)
pd.set_option('display.max_rows',100)

plt.style.use('dark_background')

# %%
from tensorflow.keras.models import Model

def visualize_layer_outputs(model, image, n):
    """
    Pass an image through the first `n` layers of the model and plot output channels.

    Parameters:
    - model: Keras Sequential model
    - image: single input image (shape must match model input)
    - n: number of layers to include
    """
    # Ensure image has batch dimension
    if image.ndim == 3:
        image = np.expand_dims(image, axis=0)
    
    # Create a model up to the nth layer
    truncated_model = Model(inputs=model.inputs, outputs=model.layers[n].output)

    # Get activations
    activations = truncated_model.predict(image)
    
    # Squeeze batch dimension if needed
    if activations.ndim == 4:
        activations = np.squeeze(activations, axis=0)  # shape: (H, W, C)

    n_channels = activations.shape[-1]

    # Set up subplot grid
    n_cols = 4
    n_rows = int(np.ceil((n_channels + 1) / n_cols))  # +1 for original image
    size = 4
    
    plt.figure(figsize=(size * n_cols, size * n_rows))

    # Plot original image
    plt.subplot(n_rows, n_cols, 1)
    if image.shape[-1] == 1:
        plt.imshow(image[0, ..., 0], cmap='gray')
    else:
        plt.imshow(image[0])
    plt.title("Original")

    # Plot each channel
    for i in range(n_channels):
        plt.subplot(n_rows, n_cols, i + 2)
        plt.imshow(activations[..., i], cmap='gray', interpolation=None)
        plt.title(f"Channel {i}")

    plt.tight_layout()
    plt.show()

# %% [markdown]
# # Keras CNN on un-augmented CIFAR10 data

# %%
from tensorflow.keras.datasets import cifar10

# Load data
(X_train, y_train), (X_test, y_test) = cifar10.load_data()

# Print shapes
print("X_train.shape:", X_train.shape)
print("X_test.shape: ", X_test.shape)
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 ━━━━━━━━━━━━━━━━━━━━ 4s 0us/step
# X_train.shape: (50000, 32, 32, 3)
# X_test.shape:  (10000, 32, 32, 3)

# %%
# Display a random image
idx = np.random.randint(0, len(X_train))
plt.figure(figsize=(4, 4))
plt.imshow(X_train[idx])
plt.title(f"Label: {y_train[idx]}")
plt.show()

# %% [markdown]
# ## Create/train/analyze model

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import *

dropout_rate = 0.1

n_classes  = np.unique(y_train).shape[0]

# Create model
model = Sequential([
    Input(shape=X_train.shape[1:]),

    Conv2D(8, (3, 3), activation='relu', padding='same'),
    MaxPooling2D(pool_size=(2, 2)),
    BatchNormalization(),
    Dropout(dropout_rate),
    
    Conv2D(16, (3, 3), activation='relu', padding='same'),
    MaxPooling2D(pool_size=(2, 2)),
    BatchNormalization(),
    Dropout(dropout_rate),
    
    Conv2D(32, (3, 3), activation='relu', padding='same'),
    MaxPooling2D(pool_size=(2, 2)),
    BatchNormalization(),
    Dropout(dropout_rate),
    
    Conv2D(64, (3, 3), activation='relu', padding='same'),
    MaxPooling2D(pool_size=(2, 2)),
    
    GlobalAveragePooling2D(),
    Dropout(dropout_rate),
    
    Dense(32, activation='relu'),
    Dropout(dropout_rate),
    Dense(16, activation='relu'),
    
    Dense(n_classes, activation='softmax'),
])

# Display model summary
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                      │ (None, 32, 32, 8)           │             224 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d (MaxPooling2D)         │ (None, 16, 16, 8)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization                  │ (None, 16, 16, 8)           │              32 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 16, 16, 8)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_1 (Conv2D)                    │ (None, 16, 16, 16)          │           1,168 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_1 (MaxPooling2D)       │ (None, 8, 8, 16)            │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_1                │ (None, 8, 8, 16)            │              64 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_1 (Dropout)                  │ (None, 8, 8, 16)            │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_2 (Conv2D)                    │ (None, 8, 8, 32)            │           4,640 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_2 (MaxPooling2D)       │ (None, 4, 4, 32)            │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_2                │ (None, 4, 4, 32)            │             128 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_2 (Dropout)                  │ (None, 4, 4, 32)            │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_3 (Conv2D)                    │ (None, 4, 4, 64)            │          18,496 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_3 (MaxPooling2D)       │ (None, 2, 2, 64)            │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ global_average_pooling2d             │ (None, 64)                  │               0 │
# │ (GlobalAveragePooling2D)             │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_3 (Dropout)                  │ (None, 64)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 32)                  │           2,080 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_4 (Dropout)                  │ (None, 32)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 16)                  │             528 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 10)                  │             170 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 27,530 (107.54 KB)
#  Trainable params: 27,418 (107.10 KB)
#  Non-trainable params: 112 (448.00 B)

# %%
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.optimizers.schedules import ExponentialDecay, PolynomialDecay

# define training parameters
epochs          = 50
batch_size      = 256

# Define the learning rate schedule
initial_learning_rate = 0.01

optimizer = Adam(
    learning_rate=initial_learning_rate,
)

# Compile model
model.compile(
    optimizer=optimizer,
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

# Early stopping callback
early_stopping = EarlyStopping(
    monitor='val_loss',  # Monitor validation loss
    patience=10,          # Stop after 5 epochs without improvement
    restore_best_weights=True  # Restore the best weights after stopping
)

# %%
history = model.fit(
    X_train, y_train,
    epochs=epochs,
    batch_size=batch_size,
    validation_data=(X_test, y_test),
    verbose=1,
    callbacks=[early_stopping]
)
# Out:
# Epoch 1/50
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 5s 13ms/step - accuracy: 0.2912 - loss: 1.8599 - val_accuracy: 0.2973 - val_loss: 2.5563
# Epoch 2/50
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.4616 - loss: 1.4599 - val_accuracy: 0.5138 - val_loss: 1.2968
# Epoch 3/50
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.5206 - loss: 1.3158 - val_accuracy: 0.4746 - val_loss: 1.4870
# Epoch 4/50
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.5621 - loss: 1.2297 - val_accuracy: 0.5354 - val_loss: 1.2871
# Epoch 5/50
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.5802 - loss: 1.1737 - val_accuracy: 0.5646 - val_loss: 1.2440
# Epoch 6/50
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.6011 - loss: 1.1236 - val_accuracy: 0.6403 - val_loss: 1.0147
# Epoch 7/50
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.6097 - loss: 1.1016 - val_accuracy: 0.5796 - val_loss: 1.2029
# Epoch 8/50
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.6257 - loss: 1.0661 - val_accuracy: 0.6194 - val_loss: 1.0567
# Epoch 9/50
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.6300 - loss: 1.0475 - val_accuracy: 0.6453 - val_loss: 1.0328
# Epoch 10/50
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.6461 - loss: 1.0127 - val_accuracy: 0.6448 - val_loss: 1.0353
# Epoch 11/50
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.6482 - loss: 0.9938 - val_accuracy: 0.5615 - val_loss: 1.2376
# Epoch 12/50
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.6549 - loss: 0.9814 - val_accuracy: 0.6194 - val_loss: 1.0871
# Epoch 13/50
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.6605 - loss: 0.9696 - val_accuracy: 0.6617 - val_loss: 0.9661
# Epoch 14/50
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.6652 - loss: 0.9682 - val_accuracy: 0.6683 - val_loss: 0.9499
# Epoch 15/50
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.6717 - loss: 0.9533 - val_accuracy: 0.6790 - val_loss: 0.9464
# Epoch 16/50
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - accuracy: 0.6735 - loss: 0.9380 - val_accuracy: 0.6594 - val_loss: 1.0012
# Epoch 17/50
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.6778 - loss: 0.9231 - val_accuracy: 0.6825 - val_loss: 0.9096
# Epoch 18/50
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.6822 - loss: 0.9180 - val_accuracy: 0.6858 - val_loss: 0.9002
# Epoch 19/50
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.6839 - loss: 0.9090 - val_accuracy: 0.7035 - val_loss: 0.8798
# Epoch 20/50
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.6876 - loss: 0.9093 - val_accuracy: 0.5629 - val_loss: 1.3874
# Epoch 21/50
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.6949 - loss: 0.8875 - val_accuracy: 0.7091 - val_loss: 0.8515
# Epoch 22/50
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.6915 - loss: 0.8965 - val_accuracy: 0.7031 - val_loss: 0.8727
# Epoch 23/50
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.6943 - loss: 0.8823 - val_accuracy: 0.6998 - val_loss: 0.8772
# Epoch 24/50
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.6960 - loss: 0.8812 - val_accuracy: 0.7061 - val_loss: 0.8677
# Epoch 25/50
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.7037 - loss: 0.8615 - val_accuracy: 0.7152 - val_loss: 0.8380
# Epoch 26/50
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.7000 - loss: 0.8664 - val_accuracy: 0.6936 - val_loss: 0.8912
# Epoch 27/50
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.6976 - loss: 0.8728 - val_accuracy: 0.7127 - val_loss: 0.8422
# Epoch 28/50
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.7047 - loss: 0.8586 - val_accuracy: 0.6458 - val_loss: 1.0799
# Epoch 29/50
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.7061 - loss: 0.8493 - val_accuracy: 0.7153 - val_loss: 0.8350
# Epoch 30/50
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.7072 - loss: 0.8528 - val_accuracy: 0.7138 - val_loss: 0.8482
# Epoch 31/50
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.7119 - loss: 0.8392 - val_accuracy: 0.6239 - val_loss: 1.1002
# Epoch 32/50
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.7117 - loss: 0.8378 - val_accuracy: 0.7066 - val_loss: 0.8574
# Epoch 33/50
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.7102 - loss: 0.8400 - val_accuracy: 0.7096 - val_loss: 0.8653
# Epoch 34/50
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.7152 - loss: 0.8285 - val_accuracy: 0.7203 - val_loss: 0.8277
# Epoch 35/50
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.7100 - loss: 0.8344 - val_accuracy: 0.5424 - val_loss: 1.3896
# Epoch 36/50
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.7157 - loss: 0.8261 - val_accuracy: 0.7101 - val_loss: 0.8623
# Epoch 37/50
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.7189 - loss: 0.8151 - val_accuracy: 0.7041 - val_loss: 0.8863
# Epoch 38/50
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.7181 - loss: 0.8228 - val_accuracy: 0.6955 - val_loss: 0.8951
# Epoch 39/50
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.7217 - loss: 0.8084 - val_accuracy: 0.7072 - val_loss: 0.8870
# Epoch 40/50
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.7207 - loss: 0.8147 - val_accuracy: 0.7193 - val_loss: 0.8352
# Epoch 41/50
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.7154 - loss: 0.8223 - val_accuracy: 0.7107 - val_loss: 0.8502
# Epoch 42/50
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - accuracy: 0.7183 - loss: 0.8156 - val_accuracy: 0.7018 - val_loss: 0.8600
# Epoch 43/50
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.7190 - loss: 0.8110 - val_accuracy: 0.6732 - val_loss: 0.9695
# Epoch 44/50
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.7211 - loss: 0.8091 - val_accuracy: 0.7379 - val_loss: 0.7847
# Epoch 45/50
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.7253 - loss: 0.8023 - val_accuracy: 0.7240 - val_loss: 0.8071
# Epoch 46/50
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.7227 - loss: 0.8047 - val_accuracy: 0.7184 - val_loss: 0.8344
# Epoch 47/50
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.7272 - loss: 0.8013 - val_accuracy: 0.6973 - val_loss: 0.8956
# Epoch 48/50
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.7255 - loss: 0.8035 - val_accuracy: 0.7134 - val_loss: 0.8416
# Epoch 49/50
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.7232 - loss: 0.8035 - val_accuracy: 0.7052 - val_loss: 0.8478
# Epoch 50/50
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.7248 - loss: 0.7919 - val_accuracy: 0.6986 - val_loss: 0.9003

# %%
from sklearn.metrics import classification_report, confusion_matrix, ConfusionMatrixDisplay

# Get predictions
y_test_pred  = model.predict(X_test).argmax(axis=1)

# Create a figure with two subplots side by side
fig, axes = plt.subplots(1, 2, figsize=(10, 4))

# Left subplot: Training and Validation Loss
axes[0].plot(history.history['loss'], label='Training Loss')
axes[0].plot(history.history['val_loss'], label='Validation Loss')
#axes[0].set_yscale('log')
axes[0].set_title('Training and Validation Loss')
axes[0].set_xlabel('Epochs')
axes[0].set_ylabel('Loss')
axes[0].legend()

# Right subplot: Confusion Matrix (Test Data) using seaborn heatmap with vmin set to 0
cm = confusion_matrix(y_test, y_test_pred)
sns.heatmap(cm, annot=True, fmt='d', ax=axes[1], vmin=0, 
            annot_kws={"size": 12}, cmap='nipy_spectral')
axes[1].set_title('Confusion Matrix (Test Data)')
axes[1].set_xlabel('Predicted Label')
axes[1].set_ylabel('True Label')

plt.tight_layout()
plt.show()

# Print classification report for test data
report = classification_report(y_test, y_test_pred)
print(report)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
#               precision    recall  f1-score   support
#
#            0       0.80      0.74      0.77      1000
#            1       0.93      0.82      0.87      1000
#            2       0.75      0.51      0.61      1000
#            3       0.51      0.57      0.54      1000
#            4       0.61      0.81      0.70      1000
#            5       0.66      0.65      0.65      1000
#            6       0.84      0.74      0.78      1000
#            7       0.80      0.79      0.80      1000
#            8       0.80      0.89      0.85      1000
#            9       0.78      0.87      0.82      1000
#
#     accuracy                           0.74     10000
#    macro avg       0.75      0.74      0.74     10000
# weighted avg       0.75      0.74      0.74     10000

# %% [markdown]
# ## Visualize channels after processing

# %%
idx = np.random.choice( range(X_train.shape[0]), 1 )[0]

# Choose an image from your dataset
sample_img = X_train[idx]  # or any image shaped like your input

# %%
# Visualize up to the 2nd Conv2D layer (index 2)
visualize_layer_outputs(model, sample_img, n=0)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
